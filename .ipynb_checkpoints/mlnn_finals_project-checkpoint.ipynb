# %% [markdown]
# # TO BE DELETED
# ## Overview
# - [DONE] Follow the universal workflow of DLWP 4.5 (1st edition) for a dataset of your choice.
# - [DONE] ou can use the tensorflow datasets, MNIST, Reuters, IMDB and Boston Housing Price, or an external dataset. Work exclusively in a Jupyter notebook.
# - You can only use DLWP Part 1 layers (Chapters 1 - 4) i.e. restrict your models to tensorflow sequential Dense and Dropout layers.
# - Your Jupyter notebook should read as a report, not just a sequence of code cells. Structure your report with markdown headings, subheadings, tables etc.
# - You can use as much DLWP code and code from the video notebooks as you wish but you must reference all code that is not original: credit will be given for model assembly using third-party code, and extra credit may be awarded for original code.
# - Export your Jupyter notebook to html and submit. Do not submit your notebook or any data files. Submit only the html export of your notebook.
#
# ### NOT FOR ME
# (For Colab users: Colab does not have an html facility. Either:
# - Download the colab notebook and load into Jupyter; you will then be able to export as html OR follow the instructions in this blog i.e. download from colab and then reload into colab's session storage.
# - Then run the script: %%shelljupyter nbconvert --to html /Your notebook path/file.ipynb and download the html version)
#
# ## REVIEW CRITERIA
# Credit will be awarded for:
# - report structure and quality as a document
# - adherence to the deep learning workflow
# - a systematic investigation
# - interpretation of results
#
# Additional credit may be awarded for:
# - modular programming
# - external dataset (but not an online tutorial dataset)
# - extensive experimentation
# - understanding and technique that exceeds the module syllabus
#
# ## DLWP 4.5 CHAPTER SUMMARY
# - Define the problem at hand and the data on which you’ll train. Collect this data, or annotate it with labels if need be
# - Choose how you’ll measure success on your problem. Which metrics will you monitor on your validation data?
# - Determine your evaluation protocol: hold-out validation? K-fold validation? Which portion of the data should you use for validation?
# - Develop a first model that does better than a basic baseline: a model with statistical power
# - Develop a model that overfits
# - Regularize your model and tune its hyperparameters, based on performance on the validation data. A lot of machine-learning research tends to focus only on this step—but keep the big picture in mind
#
# ---

# %% [markdown]
# # The Universal Workflow of Machine Learning
# This project centers around the universal workflow of **DLWP 4.5** on the **CIFAR-10** small images classification datatset in Keras. The aim for this project is to produce a model that produces the best results through learning features through Tensorflow's sequential ```Dense``` and ```Dropout``` layers.

# %% [markdown]
# ## 1 Defining the problem
# ### 1.1 Datatype
# **Input Data:**
# - 60,000 colour images of shape (32, 32, 3)
# - Each colour images represents a different object class (vehicles and animals)
# - There are 50,000 training images, and 10,000 test images
#
# <br>**Output Data:** A classification label (0-9), representing 10 different categories
#
# <center><img src="images/CIFAR10_dataset_categories.jpg" style="width: 50%" alt="CIFAR10 Dataset Categories"></img>
# <br><b><a href="https://keras.io/api/datasets/cifar10/">1 The CIFAR-10 Dataset Categories</a><b></center>
#
# ### 1.2 Problem Type and Goals
# Classification of raw images into categories is valuable across industries. By training a model that could accurately classify images based on features and labels, Machine Learning can be implemented to aid in real-world problems like Breast Cancer Detection. ( **<a href="https://www.nejm.org/doi/full/10.1056/nejmoa1206809">2 Bleyer and Welch, 2012</a>** )
#
# - **Problem Type:** Multiclass classification - one of 10 possible classes must be assigned to each one of the 10,000 test images.
# - **Hypothesis:** The CIFAR-10 dataset is large enough and contains enough visual information for the model to learn generalised relationships between inputs and outputs such that it is able to accurately classify unseen.

# %% [markdown]
# #### TO BE DELETED
# ```Multiclass classification? Scalar regression? Vector regression? Multiclass, multilabel classification? Something else, like clustering, generation, or reinforcement learning? Identifying the problem type will guide your choice of model architecture, loss function, and so on.```

# %%
# PREPARATION FOR CODE
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import models, layers
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## 2 Assembling the dataset
# To begin, the CIFAR-10 dataset is loaded and split into its relevant ```train_images```, ```train_labels```, ```test_images```, and ```test_labels```. To understand the data better, the shape of the training and test sets are displayed. To view the different classes in the data, 10 images of each class is displayed.

# %%
# LOADING CIFAR-10 DATASET
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# EXPLORING DATASET SHAPE
print("Train Images:", train_images.shape, "Train Labels:", train_labels.shape)
print("Test Images:", test_images.shape, "Test Labels:", test_labels.shape)

# VISUALISING SAMPLES
# flattening train_labels to a 1D array
train_labels = train_labels.flatten()
# getting first 10 class IDs in order (0-9)
classes = sorted(set(train_labels))[:10]

# creating a 10 x 10 figure
fig, axes = plt.subplots(10, 10, figsize = (6, 6))

# plotting first 10 images of each class
for i, class_id in enumerate(classes):
    # find idxs of images belonging to the current class
    class_idxs = np.where(train_labels == class_id)[0]
    # select first 10 images from each class
    selected_idxs = class_idxs[:10]
    # display class label at top of column
    axes[0, i].set_title(f"Class {class_id}", fontsize = 8)
    
    # iterating over selected images
    for j, img_idx in enumerate(selected_idxs):
        # getting the image
        img = train_images[img_idx]
        # displaying image
        axes[j, i].imshow(img)
        axes[j, i].axis("off")
        
# adjusting layout
plt.tight_layout(rect = [0, 0, 1, 1])
plt.show()
# Out:
# Train Images: (50000, 32, 32, 3) Train Labels: (50000, 1)
# Test Images: (10000, 32, 32, 3) Test Labels: (10000, 1)

# %% [markdown]
# ## 3 Choosing a measure of success
# Given the description provided on CIFAR-10 ( <b><a href="https://www.cs.toronto.edu/~kriz/cifar.html">3 Krizhevsky, 2009</a><b> ):
# > "The test batch contains exactly 1000 randomly-selected images from each class."
#
# <br>The dataset is balanced, making ```accuracy``` a suitable metric. <br>The accuracy score is calculated as follows:
#
# $$
# Accuracy = \frac{TP + TN}{TP + FP + TN + FN}
# $$
#
# <br>To analyse the class-specific misclassification trends, ```confusion matrix``` will also be implemented.

# %% [markdown]
# #### TO BE DELETED
# ```To control something, you need to be able to observe it. To achieve success, you must define what you mean by success—accuracy? Precision and recall? Customer-retention rate? Your metric for success will guide the choice of a loss function: what your model will optimize. It should directly align with your higher-level goals, such as the success of your business. For balanced-classification problems, where every class is equally likely, accuracy and area under the receiver operating characteristic curve (ROC AUC) are common metrics. For class-imbalanced problems, you can use precision and recall. For ranking problems or multilabel classification, you can use mean average precision. And it isn’t uncommon to have to define your own custom metric by which to measure success. To get a sense of the diversity of machine-learning success metrics and how they relate to different problem domains, it’s helpful to browse the data science competitions on Kaggle (https://kaggle.com); they showcase a wide range of problems and evaluation metrics.```

# %% [markdown]
# ## 4 Deciding on an evaluation protocol
# To measure the current progress, the evaluation protocol chosen would be **a hold-out validation set**. Since the CIFAR-10 dataset contains **50,000 training images**, the dataset can be split into **80% training and 20% validation**. This ensures that the model learns from 40,000 training images, and 10,000 validation images are available for **unbiased evaluation** before testing it on unseen data.

# %% [markdown]
# ## 5 Preparation and baseline
# ### 5.1 Preparing your data
# To ensure that the data can be fed into the network, the data needs to be formatted as tensors. For this case, the CIFAR-10 dataset consists of images with a shape of **(32, 32, 3)**, representing **32x32 pixel RGB images**. Since the model is fully connected with Dense layers, the images need to be reshaped into 1D vectors of size **32 x 32 x 3 = 3027**. This transformation will ensure that each image is represented as a single tensor of shape **(3027, )**.
#
# Next, the pixel values are normalised by dividing the reshaped values by **255.0**, scaling them to the **[0, 1] range**. This normalisation will help to improve numerical stability which accelerates training by keeping all input values within a small, consistent range.

# %% [markdown]
# #### TO BE DELETED
# ```Once you know what you’re training on, what you’re optimizing for, and how to evaluate your approach, you’re almost ready to begin training models. But first, you should format your data in a way that can be fed into a machine-learning model — here, we’ll assume a deep neural network:```
#
# - As you saw previously, your data should be formatted as tensors
# - The values taken by these tensors should usually be scaled to small values: for example, in the [-1, 1] range or [0, 1] range
# - If different features take values in different ranges (heterogeneous data), then the data should be normalized
# - You may want to do some feature engineering, especially for small-data problems
#
# ```Once your tensors of input data and target data are ready, you can begin to train models```

# %%
# flattening images and normalising data
x_train = train_images.reshape((50000, 32*32*3)).astype("float32") / 255.0
x_test = test_images.reshape((10000, 32*32*3)).astype("float32") / 255.0
print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)

# preparing the labels
y_train = to_categorical(train_labels, num_classes = 10).astype("float")
y_test = to_categorical(test_labels, num_classes = 10).astype("float")
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (50000, 3072)
# x_test shape: (10000, 3072)
# y_train shape: (50000, 10)
# y_test shape: (10000, 10)

# %% [markdown]
# ### 5.2 Establishing baseline model
# Based on **DLWP Chapter 2**, the base model shown was replicated, and the input shape was modified to fit the 32x32 pixel RGB images. The model was then trained on training set with a batch size of 128 for 5 epochs, as shown in the reference.
#
# Compilation was done following the reference, but further developments will consider finding the best combination for the loss function and optimizer used. The following rephrased quote describes what the loss function and optimizer does:
# > The loss function determines how the network will be able to measure its performance on the training data, and thus how it will be able to steer itself in the right direction. An optimizer is the mechanism through which the network will update itself based on the data it sees and its loss function.

# %%
model = models.Sequential([
    layers.Dense(512, activation = "relu", input_shape = (32*32*3,)),
    layers.Dense(10, activation = "softmax") # 10 classes
])

model.compile( optimizer = "rmsprop", loss = "categorical_crossentropy", metrics = ["accuracy"] )
history_a = model.fit(x_train, y_train, epochs = 5, batch_size = 128)
# Out:
# Epoch 1/5
# C:\Users\sbgka\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2083 - loss: 3.0600
# Epoch 2/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3454 - loss: 1.8205
# Epoch 3/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3903 - loss: 1.7245
# Epoch 4/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4126 - loss: 1.6622
# Epoch 5/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4203 - loss: 1.6277

# %% [markdown]
# The same training was also done with the evaluation protocol of a hold-out validation set. It is noted that even with the implementation of a validation split, there was no significant improvement to the loss and accuracy, suggesting the inconclusivity of the importance of the evaluation protocol with a small number of epochs.

# %%
model = models.Sequential([
    layers.Dense(512, activation = "relu", input_shape = (32*32*3,)),
    layers.Dense(10, activation = "softmax") # 10 classes
])

model.compile( optimizer = "rmsprop", loss = "categorical_crossentropy", metrics = ["accuracy"] )
history_b = model.fit(x_train, y_train, epochs = 5, batch_size = 128, validation_split = 0.2)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2030 - loss: 3.1310 - val_accuracy: 0.3370 - val_loss: 1.8456
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3380 - loss: 1.8510 - val_accuracy: 0.3192 - val_loss: 1.8998
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3742 - loss: 1.7509 - val_accuracy: 0.3700 - val_loss: 1.7645
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3966 - loss: 1.6929 - val_accuracy: 0.4126 - val_loss: 1.6687
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4174 - loss: 1.6474 - val_accuracy: 0.4126 - val_loss: 1.6804

# %% [markdown]
# To evaluate the model's actual performance, the models will be modified to include a ```Dropout``` rate to prevent overfitting, and trained with a larger number of epochs. These new models will then be evaluated on the test set. To confirm that the evaluation protocol was successful, the training accuracy and loss will be plotted.
#
# Based on the output, it is proven that after adding a ```Dropout``` to the model, including a validation split has significantly improved the test accuracy whilst decreasing the model's loss. It is also noted that the ```val_accuracy``` has an **overall decreasing trend**, whilst the ```val_loss``` has an **overall increasing trend**.

# %%
def build_model():
    model = models.Sequential([
        layers.Dense(512, activation = "relu", input_shape = (32*32*3,)),
        layers.Dropout(0.3),
        layers.Dense(10, activation = "softmax") # 10 classes
    ])

    model.compile(
        optimizer = "rmsprop",
        loss = "categorical_crossentropy",
        metrics = ["accuracy"]
    )
    
    return model

model_wo_val = build_model()
history_a = model.fit(x_train, y_train, epochs = 100, batch_size = 128)
model_w_val = build_model()
history_b = model.fit(x_train, y_train, epochs = 100, batch_size = 128, validation_split = 0.2)
# Out:
# Epoch 1/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4229 - loss: 1.6218
# Epoch 2/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4435 - loss: 1.5781
# Epoch 3/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4503 - loss: 1.5596
# Epoch 4/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4535 - loss: 1.5420
# Epoch 5/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4632 - loss: 1.5111
# Epoch 6/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4745 - loss: 1.4903
# Epoch 7/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4758 - loss: 1.4785
# Epoch 8/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4828 - loss: 1.4643
# Epoch 9/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4888 - loss: 1.4451
# Epoch 10/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4965 - loss: 1.4280
# Epoch 11/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4995 - loss: 1.4173
# Epoch 12/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5082 - loss: 1.4057
# Epoch 13/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5043 - loss: 1.4032
# Epoch 14/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5124 - loss: 1.3781
# Epoch 15/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5170 - loss: 1.3670
# Epoch 16/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5193 - loss: 1.3579
# Epoch 17/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5267 - loss: 1.3499
# Epoch 18/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5272 - loss: 1.3406
# Epoch 19/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5328 - loss: 1.3304
# Epoch 20/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5340 - loss: 1.3187
# Epoch 21/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5417 - loss: 1.3053
# Epoch 22/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5356 - loss: 1.3087
# Epoch 23/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5429 - loss: 1.2992
# Epoch 24/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5463 - loss: 1.2947
# Epoch 25/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5496 - loss: 1.2754
# Epoch 26/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5535 - loss: 1.2676
# Epoch 27/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5564 - loss: 1.2641
# Epoch 28/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5590 - loss: 1.2492
# Epoch 29/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5631 - loss: 1.2446
# Epoch 30/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5603 - loss: 1.2376
# Epoch 31/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5706 - loss: 1.2297
# Epoch 32/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5692 - loss: 1.2236
# Epoch 33/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5777 - loss: 1.2073
# Epoch 34/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5751 - loss: 1.2139
# Epoch 35/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5765 - loss: 1.2035
# Epoch 36/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5732 - loss: 1.2108
# Epoch 37/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5803 - loss: 1.1918
# Epoch 38/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5859 - loss: 1.1698
# Epoch 39/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5890 - loss: 1.1793
# Epoch 40/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5839 - loss: 1.1770
# Epoch 41/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5979 - loss: 1.1564
# Epoch 42/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5933 - loss: 1.1518
# Epoch 43/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5966 - loss: 1.1463
# Epoch 44/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6012 - loss: 1.1358
# Epoch 45/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5981 - loss: 1.1413
# Epoch 46/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5991 - loss: 1.1388
# Epoch 47/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6035 - loss: 1.1252
# Epoch 48/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6071 - loss: 1.1226
# Epoch 49/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6056 - loss: 1.1120
# Epoch 50/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6096 - loss: 1.1122
# Epoch 51/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6061 - loss: 1.1149
# Epoch 52/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6127 - loss: 1.0956
# Epoch 53/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6089 - loss: 1.0954
# Epoch 54/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6192 - loss: 1.0787
# Epoch 55/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6141 - loss: 1.0872
# Epoch 56/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6180 - loss: 1.0805
# Epoch 57/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6238 - loss: 1.0726
# Epoch 58/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6236 - loss: 1.0664
# Epoch 59/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6214 - loss: 1.0684
# Epoch 60/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6260 - loss: 1.0656
# Epoch 61/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6273 - loss: 1.0564
# Epoch 62/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6253 - loss: 1.0660
# Epoch 63/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6265 - loss: 1.0522
# Epoch 64/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6305 - loss: 1.0465
# Epoch 65/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6388 - loss: 1.0315
# Epoch 66/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6334 - loss: 1.0261
# Epoch 67/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6299 - loss: 1.0389
# Epoch 68/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6356 - loss: 1.0366
# Epoch 69/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6374 - loss: 1.0323
# Epoch 70/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6426 - loss: 1.0208
# Epoch 71/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6388 - loss: 1.0175
# Epoch 72/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6418 - loss: 1.0151
# Epoch 73/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6424 - loss: 1.0114
# Epoch 74/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6461 - loss: 1.0043
# Epoch 75/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6493 - loss: 1.0004
# Epoch 76/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6472 - loss: 0.9938
# Epoch 77/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6458 - loss: 1.0027
# Epoch 78/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6525 - loss: 0.9849
# Epoch 79/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6505 - loss: 0.9900
# Epoch 80/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6518 - loss: 0.9876
# Epoch 81/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6547 - loss: 0.9858
# Epoch 82/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6543 - loss: 0.9810
# Epoch 83/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6597 - loss: 0.9673
# Epoch 84/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6575 - loss: 0.9686
# Epoch 85/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6600 - loss: 0.9761
# Epoch 86/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6591 - loss: 0.9635
# Epoch 87/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6588 - loss: 0.9643
# Epoch 88/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6605 - loss: 0.9653
# Epoch 89/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6599 - loss: 0.9617
# Epoch 90/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6655 - loss: 0.9474
# Epoch 91/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6631 - loss: 0.9501
# Epoch 92/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6641 - loss: 0.9530
# Epoch 93/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6684 - loss: 0.9432
# Epoch 94/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6657 - loss: 0.9389
# Epoch 95/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6709 - loss: 0.9290
# Epoch 96/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6725 - loss: 0.9332
# Epoch 97/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6680 - loss: 0.9381
# Epoch 98/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6681 - loss: 0.9337
# Epoch 99/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6722 - loss: 0.9194
# Epoch 100/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6755 - loss: 0.9198
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6724 - loss: 0.9247 - val_accuracy: 0.6431 - val_loss: 0.9874
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6795 - loss: 0.8964 - val_accuracy: 0.6355 - val_loss: 1.0708
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6820 - loss: 0.9019 - val_accuracy: 0.6527 - val_loss: 0.9822
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6835 - loss: 0.9044 - val_accuracy: 0.6533 - val_loss: 0.9803
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6840 - loss: 0.8974 - val_accuracy: 0.6539 - val_loss: 0.9848
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6885 - loss: 0.8818 - val_accuracy: 0.6422 - val_loss: 1.0433
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6892 - loss: 0.8795 - val_accuracy: 0.6112 - val_loss: 1.1537
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6896 - loss: 0.8854 - val_accuracy: 0.6170 - val_loss: 1.1117
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6893 - loss: 0.8795 - val_accuracy: 0.6323 - val_loss: 1.0398
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6866 - loss: 0.8831 - val_accuracy: 0.6286 - val_loss: 1.0694
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6902 - loss: 0.8756 - val_accuracy: 0.6154 - val_loss: 1.1282
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6918 - loss: 0.8747 - val_accuracy: 0.6293 - val_loss: 1.0751
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6955 - loss: 0.8604 - val_accuracy: 0.6282 - val_loss: 1.0811
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6914 - loss: 0.8665 - val_accuracy: 0.5907 - val_loss: 1.2179
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6942 - loss: 0.8669 - val_accuracy: 0.6142 - val_loss: 1.1563
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6960 - loss: 0.8590 - val_accuracy: 0.6114 - val_loss: 1.1383
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6997 - loss: 0.8520 - val_accuracy: 0.6113 - val_loss: 1.1416
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7007 - loss: 0.8510 - val_accuracy: 0.5674 - val_loss: 1.3718
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7001 - loss: 0.8549 - val_accuracy: 0.6123 - val_loss: 1.1485
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7020 - loss: 0.8460 - val_accuracy: 0.6068 - val_loss: 1.1808
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7018 - loss: 0.8466 - val_accuracy: 0.6262 - val_loss: 1.1150
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7024 - loss: 0.8354 - val_accuracy: 0.6093 - val_loss: 1.1545
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7035 - loss: 0.8462 - val_accuracy: 0.6146 - val_loss: 1.1473
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7010 - loss: 0.8508 - val_accuracy: 0.5968 - val_loss: 1.2133
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7014 - loss: 0.8421 - val_accuracy: 0.6181 - val_loss: 1.1530
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7090 - loss: 0.8205 - val_accuracy: 0.5895 - val_loss: 1.2420
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7073 - loss: 0.8288 - val_accuracy: 0.6020 - val_loss: 1.2141
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7108 - loss: 0.8149 - val_accuracy: 0.5938 - val_loss: 1.2497
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7020 - loss: 0.8261 - val_accuracy: 0.6145 - val_loss: 1.1747
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7140 - loss: 0.8168 - val_accuracy: 0.6199 - val_loss: 1.1631
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7136 - loss: 0.8143 - val_accuracy: 0.5816 - val_loss: 1.3016
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7168 - loss: 0.8008 - val_accuracy: 0.6014 - val_loss: 1.2346
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7126 - loss: 0.8127 - val_accuracy: 0.5937 - val_loss: 1.2602
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7091 - loss: 0.8179 - val_accuracy: 0.6114 - val_loss: 1.1964
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7147 - loss: 0.8105 - val_accuracy: 0.5931 - val_loss: 1.2877
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7161 - loss: 0.8080 - val_accuracy: 0.5653 - val_loss: 1.3596
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7139 - loss: 0.8025 - val_accuracy: 0.5874 - val_loss: 1.3131
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7164 - loss: 0.7978 - val_accuracy: 0.5909 - val_loss: 1.2885
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7220 - loss: 0.7953 - val_accuracy: 0.5688 - val_loss: 1.4448
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7184 - loss: 0.7912 - val_accuracy: 0.5686 - val_loss: 1.4458
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7195 - loss: 0.7942 - val_accuracy: 0.5615 - val_loss: 1.4372
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7202 - loss: 0.7955 - val_accuracy: 0.5403 - val_loss: 1.5419
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7200 - loss: 0.7832 - val_accuracy: 0.6064 - val_loss: 1.2542
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7256 - loss: 0.7822 - val_accuracy: 0.5795 - val_loss: 1.4045
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7227 - loss: 0.7808 - val_accuracy: 0.5423 - val_loss: 1.5096
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7211 - loss: 0.7891 - val_accuracy: 0.5922 - val_loss: 1.3149
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7242 - loss: 0.7730 - val_accuracy: 0.5474 - val_loss: 1.6159
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7230 - loss: 0.7767 - val_accuracy: 0.5718 - val_loss: 1.4363
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7240 - loss: 0.7815 - val_accuracy: 0.5897 - val_loss: 1.3247
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7257 - loss: 0.7666 - val_accuracy: 0.5880 - val_loss: 1.3456
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7316 - loss: 0.7579 - val_accuracy: 0.5778 - val_loss: 1.3938
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7275 - loss: 0.7707 - val_accuracy: 0.5611 - val_loss: 1.5299
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7249 - loss: 0.7733 - val_accuracy: 0.5762 - val_loss: 1.4652
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7326 - loss: 0.7668 - val_accuracy: 0.5772 - val_loss: 1.3942
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7332 - loss: 0.7485 - val_accuracy: 0.5856 - val_loss: 1.3802
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7326 - loss: 0.7515 - val_accuracy: 0.5652 - val_loss: 1.5975
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7338 - loss: 0.7605 - val_accuracy: 0.5367 - val_loss: 1.7185
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7293 - loss: 0.7646 - val_accuracy: 0.5620 - val_loss: 1.4655
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7334 - loss: 0.7571 - val_accuracy: 0.5762 - val_loss: 1.4448
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7363 - loss: 0.7534 - val_accuracy: 0.5891 - val_loss: 1.4170
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7381 - loss: 0.7443 - val_accuracy: 0.5845 - val_loss: 1.4045
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7396 - loss: 0.7362 - val_accuracy: 0.5690 - val_loss: 1.5282
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7417 - loss: 0.7312 - val_accuracy: 0.5742 - val_loss: 1.5147
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7373 - loss: 0.7403 - val_accuracy: 0.5804 - val_loss: 1.4117
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7400 - loss: 0.7328 - val_accuracy: 0.5792 - val_loss: 1.4482
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7443 - loss: 0.7261 - val_accuracy: 0.5723 - val_loss: 1.4811
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7382 - loss: 0.7356 - val_accuracy: 0.5744 - val_loss: 1.5379
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7390 - loss: 0.7337 - val_accuracy: 0.5770 - val_loss: 1.4674
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7467 - loss: 0.7156 - val_accuracy: 0.5748 - val_loss: 1.4724
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7416 - loss: 0.7317 - val_accuracy: 0.5144 - val_loss: 1.8389
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7415 - loss: 0.7313 - val_accuracy: 0.5886 - val_loss: 1.4010
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7470 - loss: 0.7185 - val_accuracy: 0.5720 - val_loss: 1.5253
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7439 - loss: 0.7241 - val_accuracy: 0.5748 - val_loss: 1.4900
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7486 - loss: 0.7230 - val_accuracy: 0.5790 - val_loss: 1.5050
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7531 - loss: 0.7088 - val_accuracy: 0.5618 - val_loss: 1.5944
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7495 - loss: 0.7086 - val_accuracy: 0.5540 - val_loss: 1.6382
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7492 - loss: 0.7129 - val_accuracy: 0.5799 - val_loss: 1.5186
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7447 - loss: 0.7131 - val_accuracy: 0.5304 - val_loss: 1.6851
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7463 - loss: 0.7136 - val_accuracy: 0.5634 - val_loss: 1.6375
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7483 - loss: 0.7164 - val_accuracy: 0.5642 - val_loss: 1.5853
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7540 - loss: 0.7010 - val_accuracy: 0.5544 - val_loss: 1.6580
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7473 - loss: 0.7083 - val_accuracy: 0.5683 - val_loss: 1.6377
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7495 - loss: 0.7076 - val_accuracy: 0.5737 - val_loss: 1.6097
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7516 - loss: 0.7153 - val_accuracy: 0.5597 - val_loss: 1.6098
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7551 - loss: 0.6887 - val_accuracy: 0.5628 - val_loss: 1.6500
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7542 - loss: 0.7028 - val_accuracy: 0.5630 - val_loss: 1.6159
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7536 - loss: 0.6872 - val_accuracy: 0.5493 - val_loss: 1.6774
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7578 - loss: 0.6901 - val_accuracy: 0.5650 - val_loss: 1.7131
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7539 - loss: 0.6862 - val_accuracy: 0.5530 - val_loss: 1.7352
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7560 - loss: 0.6919 - val_accuracy: 0.5475 - val_loss: 1.8604
# Epoch 91/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7551 - loss: 0.6906 - val_accuracy: 0.5345 - val_loss: 1.7812
# Epoch 92/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7593 - loss: 0.6833 - val_accuracy: 0.5637 - val_loss: 1.7177
# Epoch 93/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7549 - loss: 0.6869 - val_accuracy: 0.5563 - val_loss: 1.7519
# Epoch 94/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7591 - loss: 0.6800 - val_accuracy: 0.5564 - val_loss: 1.6762
# Epoch 95/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7591 - loss: 0.6806 - val_accuracy: 0.5496 - val_loss: 1.7496
# Epoch 96/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7553 - loss: 0.6985 - val_accuracy: 0.5596 - val_loss: 1.7310
# Epoch 97/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7584 - loss: 0.6889 - val_accuracy: 0.5584 - val_loss: 1.7098
# Epoch 98/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7582 - loss: 0.6849 - val_accuracy: 0.5563 - val_loss: 1.7247
# Epoch 99/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7608 - loss: 0.6797 - val_accuracy: 0.5186 - val_loss: 2.0180
# Epoch 100/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7626 - loss: 0.6700 - val_accuracy: 0.5585 - val_loss: 1.7353

# %%
# evaluating model on test set
test_loss, test_acc = model_wo_val.evaluate(x_test, y_test)
test_loss_val, test_acc_val = model_w_val.evaluate(x_test, y_test)

# DISPLAYING TEST ACCURACY
print(f"Test Accuracy WITHOUT Validation Split: {test_acc}")
print(f"Test Accuracy WITH Validation Split: {test_acc_val}")

# PLOTTING LEARNING CURVE
fig, axes = plt.subplots(1, 2, figsize = (12, 5))
# plotting accuracy
axes[0].plot(history_a.history["accuracy"], label = "Accuracy (No Val)")
axes[0].plot(history_b.history["accuracy"], label = "Accuracy (With Val)")
axes[0].plot(history_b.history["val_accuracy"], label = "Validation")
axes[0].set_title("Training Accuracy Comparison")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Accuracy")
axes[0].legend()
# plotting loss
axes[1].plot(history_a.history["loss"], label = "Loss (No Val)")
axes[1].plot(history_b.history["loss"], label = "Loss (With Val)")
axes[1].plot(history_b.history["val_loss"], label = "Validation")
axes[1].set_title("Training Loss Comparison")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("Accuracy")
axes[1].legend()
# plotting graph
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.1254 - loss: 2.4583
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.1043 - loss: 2.6061
# Test Accuracy WITHOUT Validation Split: 0.125900000333786
# Test Accuracy WITH Validation Split: 0.10249999910593033

# %% [markdown]
# Note that the confusion matrix does not seem to be working well for this section

# %%
# GENERATING CONFUSION MATRIX
def get_conf_matrix(model):
    # predicting class probability
    y_pred = model.predict(x_test)
    # converting to one-hot to class indices
    y_pred_classes = np.argmax(y_pred, axis = 1)
    y_true_classes = np.argmax(y_test, axis = 1)
    # generating confusion matrix
    return confusion_matrix(y_true_classes, y_pred_classes), classification_report(y_true_classes, y_pred_classes)

cm_a, cr_a = get_conf_matrix(model_wo_val)
cm_b, cr_b = get_conf_matrix(model_w_val)

# DISPLAYING CLASSIFICATION REPORT
print("\nClassification Report w/o Validation:")
print(cr_a)
print("\nClassification Report w/ Validation:")
print(cr_b)

# PLOTTING SIDE-BY-SIDE HEATMAPS
fig, axes = plt.subplots(1, 2, figsize = (12, 5))
# getting heatmap for model without validation
sns.heatmap(cm_a, annot = True,
            fmt = "d", cmap = "Blues",
            xticklabels = range(10), yticklabels = range(10), ax = axes[0])
axes[0].set_xlabel("Predicted Label")
axes[0].set_ylabel("True Label")
axes[0].set_title("Confusion Matrix Heatmap: No Validation Split")
# getting heatmap for model with validation
sns.heatmap(cm_b, annot = True,
            fmt = "d", cmap = "Blues",
            xticklabels = range(10), yticklabels = range(10), ax = axes[1])
axes[1].set_xlabel("Predicted Label")
axes[1].set_ylabel("True Label")
axes[1].set_title("Confusion Matrix Heatmap: With Validation Split")

plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 227/313 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# C:\Users\sbgka\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\sbgka\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\sbgka\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
#
# Classification Report w/o Validation:
#               precision    recall  f1-score   support
#
#            0       0.12      0.88      0.22      1000
#            1       0.02      0.00      0.00      1000
#            2       0.00      0.00      0.00      1000
#            3       0.15      0.02      0.03      1000
#            4       0.07      0.06      0.06      1000
#            5       0.00      0.00      0.00      1000
#            6       0.19      0.28      0.23      1000
#            7       0.00      0.00      0.00      1000
#            8       0.06      0.02      0.03      1000
#            9       0.00      0.00      0.00      1000
#
#     accuracy                           0.13     10000
#    macro avg       0.06      0.13      0.06     10000
# weighted avg       0.06      0.13      0.06     10000
#
#
# Classification Report w/ Validation:
#               precision    recall  f1-score   support
#
#            0       0.14      0.35      0.20      1000
#            1       0.00      0.00      0.00      1000
#            2       0.00      0.00      0.00      1000
#            3       0.09      0.66      0.16      1000
#            4       0.20      0.00      0.00      1000
#            5       0.00      0.00      0.00      1000
#            6       0.12      0.02      0.03      1000
#            7       0.00      0.00      0.00      1000
#            8       0.00      0.00      0.00      1000
#            9       0.00      0.00      0.00      1000
#
#     accuracy                           0.10     10000
#    macro avg       0.05      0.10      0.04     10000
# weighted avg       0.05      0.10      0.04     10000
# C:\Users\sbgka\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\sbgka\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\sbgka\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## 5 Developing a model that does better than a baseline
# In this stage, the goal is to achieve statistical power, a model is to be developed capable of beating the current baseline model that has an accuracy of 0.10 after implementing a validation split. To view the performance, a function ```disp_performance()``` is created to display the ```accuracy```, ```val_accuracy```, ```loss``` and ```val_loss```, together with the confusion matrix.

# %% [markdown]
# #### TO BE DELETED
# ```Your goal at this stage is to achieve statistical power: that is, to develop a small model that is capable of beating a dumb baseline. In the MNIST digit-classification example, anything that achieves an accuracy greater than 0.1 can be said to have statistical power; in the IMDB example, it’s anything with an accuracy greater than 0.5.```
#
# ```Note that it’s not always possible to achieve statistical power. If you can’t beat a random baseline after trying multiple reasonable architectures, it may be that the answer to the question you’re asking isn’t present in the input data. Remember that you make two hypotheses:```
#
# - You hypothesize that your outputs can be predicted given your inputs
# - You hypothesize that the available data is sufficiently informative to learn the relationship between inputs and outputs
#
# ```It may well be that these hypotheses are false, in which case you must go back to the drawing board.```
# ```Assuming that things go well, you need to make three key choices to build your first working model:```
#
# - Last-layer activation: This establishes useful constraints on the network’s output. For instance, the IMDB classification example used sigmoid in the last layer; the regression example didn’t use any last-layer activation; and so on
# - Loss function: This should match the type of problem you’re trying to solve. For instance, the IMDB example used binary_crossentropy, the regression example used mse, and so on
# - Optimization configuration: What optimizer will you use? What will its learning rate be? In most cases, it’s safe to go with rmsprop and its default learning rate
#
# ```Regarding the choice of a loss function, note that it isn’t always possible to directly optimize for the metric that measures success on a problem. Sometimes there is no easy way to turn a metric into a loss function; loss functions, after all, need to be computable given only a mini-batch of data (ideally, a loss function should be computable for as little as a single data point) and must be differentiable (otherwise, you can’t use backpropagation to train your network). For instance, the widely used classification metric ROC AUC can’t be directly optimized. Hence, in classification tasks, it’s common to optimize for a proxy metric of ROC AUC, such as crossentropy. In general, you can hope that the lower the crossentropy gets, the higher the ROC AUC will be. Table 4.1 can help you choose a last-layer activation and a loss function for a few common problem types.```

# %%
# FUNCTION TO DISPLAY RESULTS
def disp_performance(model, history):
    # evaluating model on test set
    test_loss, test_acc = model.evaluate(x_test, y_test)
    # DISPLAYING TEST ACCURACY
    print(f"Test Accuracy: {test_acc}")
    
    # PLOTTING LEARNING CURVE
    fig, axes = plt.subplots(1, 3, figsize = (16, 5))
    # plotting accuracy
    axes[0].plot(history.history["accuracy"], label = "Accuracy")
    axes[0].plot(history.history["val_accuracy"], label = "Validation")
    axes[0].set_title("Training Accuracy")
    axes[0].set_xlabel("Epochs")
    axes[0].set_ylabel("Accuracy")
    axes[0].legend()
    # plotting loss
    axes[1].plot(history.history["loss"], label = "Loss")
    axes[1].plot(history.history["val_loss"], label = "Validation")
    axes[1].set_title("Training Loss Comparison")
    axes[1].set_xlabel("Epochs")
    axes[1].set_ylabel("Accuracy")
    axes[1].legend()

    # GENERATING CONFUSION MATRIX
    # predicting class probability
    y_pred = model.predict(x_test)
    # converting to one-hot to class indices
    y_pred_classes = np.argmax(y_pred, axis = 1)
    y_true_classes = np.argmax(y_test, axis = 1)
    # generating confusion matrix
    cm = confusion_matrix(y_true_classes, y_pred_classes)
    cr = classification_report(y_true_classes, y_pred_classes)

    # DISPLAYING CLASSIFICATION REPORT
    print("\nClassification Report:")
    print(cr)

    # PLOTTING HEATMAPS
    # getting heatmap for model without validation
    sns.heatmap(cm, annot = True,
                fmt = "d", cmap = "Blues",
                xticklabels = range(10), yticklabels = range(10), ax = axes[2])
    axes[2].set_xlabel("Predicted Label")
    axes[2].set_ylabel("True Label")
    axes[2].set_title("Confusion Matrix Heatmap")
    
    plt.tight_layout()
    plt.show()

# # TESTING FUNCTION WORKS
# model = models.Sequential([
#     layers.Dense(512, activation = "relu", input_shape = (32*32*3,)),
#     layers.Dense(10, activation = "softmax") # 10 classes
# ])

# model.compile( optimizer = "rmsprop", loss = "categorical_crossentropy", metrics = ["accuracy"] )
# history = model.fit(x_train, y_train, epochs = 5, batch_size = 128, validation_split = 0.2)
# disp_performance(model, history)

# %% [markdown]
# ### 5.1 Determining compilation combination
# To ensure that the model is compiled with the best combination of loss function and optimizer, this step will focus on finding the right loss function and optimizer for the CIFAR-10 dataset. To build the models with a base template, a function ```build_model2()``` takes in combinations of loss functions and optimizers and builds the models.

# %%
def build_model2(model_opt, model_loss):
    model = models.Sequential([
        layers.Dense(512, activation = "relu", input_shape = (32*32*3,)),
        layers.Dropout(0.3),
        layers.Dense(10, activation = "softmax") # 10 classes
    ])

    model.compile(
        optimizer = model_opt,
        loss = model_loss,
        metrics = ["accuracy"]
    )
    
    return model

# %% [markdown]
# #### 5.1.1 Determining optimizer
# For this project, the optimizers to be compared are ```RMSprop``` and ```Adam```.
#
# - ```RMSprop``` is chosen as it was used in the DLWP Book, ```RMSprop``` focuses on maintaining a moving (discounted) average of the square of gradients, then divides the gradient by the root of this average.
# - ```Adam``` is chosen as it is a stochastic gradient descent method based on adaptive estimation of first-order and second-order moments. The method is "computationally efficient, has little memory requirement, invariant to diagonal rescaling of gradients, and is well suited for problems that are large in terms of data/parameters" ( <b><a href="https://arxiv.org/abs/1412.6980">Kingma and Ba, 2014</a><b> ).
#
# #### 5.1.2 Determining loss function
# For this project, the loss functions to be compared are ```CategoricalCrossentropy```, ```CategoricalFocalCrossentropy``` and ```SparseCategoricalCrossentropy```. However, after understanding its use, ```CategoricalCrossentropy``` was the chosen loss.
#
# - ```CategoricalCrossentropy``` is chosen as it was used in the DLWP Book. ```CategoricalCrossentropy``` is generally used when there are 2 or more label classes.
# - ```CategoricalFocalCrossentropy``` is chosen as it helps the model to focus on harder-to-classify examples. It is noted, however, that this is used if the dataset is imbalanced.
# - ```SparseCategoricalCrossentropy``` is chosen to provide labels as integers. This is generally used when the labels are integers, not one-hot.

# %%
mRMS_cat = build_model2("RMSprop", "categorical_crossentropy")
history1 = mRMS_cat.fit(x_train, y_train, epochs = 100, batch_size = 128, validation_split = 0.2)
mAdam_cat = build_model2("Adam", "categorical_crossentropy")
history2 = mAdam_cat.fit(x_train, y_train, epochs = 100, batch_size = 128, validation_split = 0.2)
mRMS_focal = build_model2("RMSprop", "categorical_focal_crossentropy")
history3 = mRMS_focal.fit(x_train, y_train, epochs = 100, batch_size = 128, validation_split = 0.2)
mAdam_focal = build_model2("Adam", "categorical_focal_crossentropy")
history4 = mAdam_focal.fit(x_train, y_train, epochs = 100, batch_size = 128, validation_split = 0.2)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1926 - loss: 3.0251 - val_accuracy: 0.2991 - val_loss: 1.9177
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3109 - loss: 1.9167 - val_accuracy: 0.3312 - val_loss: 1.8261
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3397 - loss: 1.8450 - val_accuracy: 0.3494 - val_loss: 1.8201
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3562 - loss: 1.8032 - val_accuracy: 0.3769 - val_loss: 1.7390
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3666 - loss: 1.7714 - val_accuracy: 0.3966 - val_loss: 1.6889
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3727 - loss: 1.7450 - val_accuracy: 0.3863 - val_loss: 1.6989
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3816 - loss: 1.7246 - val_accuracy: 0.3839 - val_loss: 1.7189
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3870 - loss: 1.7188 - val_accuracy: 0.4177 - val_loss: 1.6562
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3946 - loss: 1.6930 - val_accuracy: 0.4074 - val_loss: 1.6777
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3995 - loss: 1.6834 - val_accuracy: 0.4072 - val_loss: 1.6939
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4056 - loss: 1.6697 - val_accuracy: 0.4261 - val_loss: 1.6235
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4090 - loss: 1.6562 - val_accuracy: 0.4239 - val_loss: 1.6373
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4099 - loss: 1.6522 - val_accuracy: 0.4317 - val_loss: 1.6006
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4091 - loss: 1.6438 - val_accuracy: 0.4373 - val_loss: 1.6000
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4144 - loss: 1.6440 - val_accuracy: 0.4271 - val_loss: 1.6021
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4184 - loss: 1.6362 - val_accuracy: 0.4400 - val_loss: 1.5981
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4249 - loss: 1.6272 - val_accuracy: 0.4287 - val_loss: 1.6484
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4275 - loss: 1.6102 - val_accuracy: 0.4171 - val_loss: 1.6085
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4243 - loss: 1.6151 - val_accuracy: 0.4369 - val_loss: 1.5989
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4230 - loss: 1.6093 - val_accuracy: 0.4267 - val_loss: 1.6439
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4270 - loss: 1.6093 - val_accuracy: 0.4404 - val_loss: 1.5954
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4284 - loss: 1.5908 - val_accuracy: 0.4230 - val_loss: 1.6268
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4405 - loss: 1.5785 - val_accuracy: 0.4484 - val_loss: 1.5986
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4400 - loss: 1.5835 - val_accuracy: 0.4391 - val_loss: 1.6079
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4409 - loss: 1.5759 - val_accuracy: 0.4307 - val_loss: 1.6051
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4404 - loss: 1.5653 - val_accuracy: 0.4498 - val_loss: 1.5402
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4396 - loss: 1.5651 - val_accuracy: 0.4655 - val_loss: 1.5311
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4419 - loss: 1.5612 - val_accuracy: 0.4278 - val_loss: 1.6269
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4474 - loss: 1.5560 - val_accuracy: 0.4588 - val_loss: 1.5351
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4525 - loss: 1.5394 - val_accuracy: 0.4496 - val_loss: 1.5673
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4514 - loss: 1.5423 - val_accuracy: 0.4701 - val_loss: 1.5525
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4434 - loss: 1.5536 - val_accuracy: 0.4613 - val_loss: 1.5486
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4511 - loss: 1.5376 - val_accuracy: 0.4272 - val_loss: 1.6423
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4499 - loss: 1.5349 - val_accuracy: 0.4537 - val_loss: 1.5985
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4539 - loss: 1.5353 - val_accuracy: 0.4451 - val_loss: 1.5881
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4539 - loss: 1.5249 - val_accuracy: 0.4544 - val_loss: 1.5808
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4544 - loss: 1.5183 - val_accuracy: 0.4596 - val_loss: 1.5754
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4557 - loss: 1.5185 - val_accuracy: 0.4539 - val_loss: 1.5708
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4527 - loss: 1.5258 - val_accuracy: 0.4542 - val_loss: 1.5817
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4586 - loss: 1.5180 - val_accuracy: 0.4736 - val_loss: 1.5147
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4621 - loss: 1.5130 - val_accuracy: 0.4613 - val_loss: 1.5396
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4635 - loss: 1.5029 - val_accuracy: 0.4508 - val_loss: 1.5708
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4603 - loss: 1.5095 - val_accuracy: 0.4158 - val_loss: 1.7477
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4607 - loss: 1.5128 - val_accuracy: 0.4404 - val_loss: 1.6526
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4659 - loss: 1.4972 - val_accuracy: 0.4608 - val_loss: 1.5627
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4679 - loss: 1.4852 - val_accuracy: 0.4587 - val_loss: 1.5481
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4662 - loss: 1.4814 - val_accuracy: 0.4367 - val_loss: 1.6699
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4750 - loss: 1.4748 - val_accuracy: 0.4598 - val_loss: 1.5630
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4644 - loss: 1.4911 - val_accuracy: 0.4658 - val_loss: 1.5587
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4722 - loss: 1.4816 - val_accuracy: 0.4619 - val_loss: 1.5792
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4698 - loss: 1.4828 - val_accuracy: 0.4536 - val_loss: 1.5635
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4709 - loss: 1.4747 - val_accuracy: 0.4661 - val_loss: 1.5547
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4723 - loss: 1.4799 - val_accuracy: 0.4535 - val_loss: 1.5971
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4746 - loss: 1.4712 - val_accuracy: 0.4564 - val_loss: 1.6230
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4698 - loss: 1.4730 - val_accuracy: 0.4540 - val_loss: 1.5823
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4692 - loss: 1.4747 - val_accuracy: 0.4605 - val_loss: 1.5689
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4781 - loss: 1.4629 - val_accuracy: 0.4672 - val_loss: 1.5777
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4778 - loss: 1.4679 - val_accuracy: 0.4335 - val_loss: 1.6814
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4782 - loss: 1.4594 - val_accuracy: 0.4583 - val_loss: 1.5954
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4843 - loss: 1.4493 - val_accuracy: 0.4677 - val_loss: 1.5534
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4759 - loss: 1.4609 - val_accuracy: 0.4615 - val_loss: 1.6078
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4810 - loss: 1.4571 - val_accuracy: 0.4775 - val_loss: 1.5831
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4834 - loss: 1.4491 - val_accuracy: 0.4521 - val_loss: 1.6114
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4846 - loss: 1.4492 - val_accuracy: 0.4459 - val_loss: 1.6419
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4777 - loss: 1.4517 - val_accuracy: 0.4605 - val_loss: 1.5820
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4817 - loss: 1.4507 - val_accuracy: 0.4569 - val_loss: 1.5792
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4893 - loss: 1.4367 - val_accuracy: 0.4521 - val_loss: 1.6361
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4812 - loss: 1.4520 - val_accuracy: 0.4651 - val_loss: 1.5699
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4847 - loss: 1.4326 - val_accuracy: 0.4600 - val_loss: 1.5951
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4912 - loss: 1.4226 - val_accuracy: 0.4612 - val_loss: 1.5815
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4903 - loss: 1.4272 - val_accuracy: 0.4562 - val_loss: 1.6433
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4888 - loss: 1.4330 - val_accuracy: 0.4605 - val_loss: 1.5901
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4913 - loss: 1.4296 - val_accuracy: 0.4627 - val_loss: 1.5901
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4927 - loss: 1.4209 - val_accuracy: 0.4311 - val_loss: 1.7545
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4932 - loss: 1.4283 - val_accuracy: 0.4373 - val_loss: 1.7082
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4929 - loss: 1.4203 - val_accuracy: 0.4470 - val_loss: 1.6475
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4882 - loss: 1.4269 - val_accuracy: 0.4523 - val_loss: 1.6090
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4900 - loss: 1.4246 - val_accuracy: 0.4741 - val_loss: 1.6023
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4926 - loss: 1.4247 - val_accuracy: 0.4763 - val_loss: 1.5626
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4922 - loss: 1.4157 - val_accuracy: 0.4673 - val_loss: 1.6181
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4883 - loss: 1.4233 - val_accuracy: 0.4794 - val_loss: 1.5962
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4969 - loss: 1.4088 - val_accuracy: 0.4647 - val_loss: 1.5848
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5005 - loss: 1.4043 - val_accuracy: 0.4510 - val_loss: 1.6220
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4969 - loss: 1.4034 - val_accuracy: 0.4465 - val_loss: 1.6667
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4973 - loss: 1.4011 - val_accuracy: 0.4576 - val_loss: 1.6087
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4966 - loss: 1.4014 - val_accuracy: 0.4734 - val_loss: 1.5922
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5004 - loss: 1.3999 - val_accuracy: 0.4564 - val_loss: 1.6256
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4982 - loss: 1.4011 - val_accuracy: 0.4753 - val_loss: 1.6058
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4979 - loss: 1.4023 - val_accuracy: 0.4468 - val_loss: 1.6817
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4982 - loss: 1.3974 - val_accuracy: 0.4391 - val_loss: 1.7203
# Epoch 91/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4982 - loss: 1.4006 - val_accuracy: 0.4490 - val_loss: 1.7228
# Epoch 92/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4968 - loss: 1.4096 - val_accuracy: 0.4580 - val_loss: 1.6061
# Epoch 93/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5023 - loss: 1.3995 - val_accuracy: 0.4721 - val_loss: 1.6017
# Epoch 94/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5024 - loss: 1.3897 - val_accuracy: 0.4698 - val_loss: 1.5874
# Epoch 95/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4989 - loss: 1.3905 - val_accuracy: 0.4551 - val_loss: 1.6422
# Epoch 96/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5026 - loss: 1.3855 - val_accuracy: 0.4627 - val_loss: 1.6447
# Epoch 97/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5013 - loss: 1.3888 - val_accuracy: 0.4698 - val_loss: 1.6289
# Epoch 98/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5001 - loss: 1.3915 - val_accuracy: 0.4740 - val_loss: 1.6034
# Epoch 99/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5027 - loss: 1.3893 - val_accuracy: 0.4625 - val_loss: 1.6681
# Epoch 100/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5116 - loss: 1.3739 - val_accuracy: 0.4557 - val_loss: 1.6636
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2411 - loss: 2.2826 - val_accuracy: 0.3408 - val_loss: 1.8655
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3292 - loss: 1.8699 - val_accuracy: 0.3731 - val_loss: 1.7634
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3476 - loss: 1.8131 - val_accuracy: 0.3805 - val_loss: 1.7394
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3588 - loss: 1.7781 - val_accuracy: 0.3923 - val_loss: 1.7159
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3620 - loss: 1.7711 - val_accuracy: 0.4016 - val_loss: 1.7026
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3704 - loss: 1.7532 - val_accuracy: 0.4054 - val_loss: 1.7011
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3786 - loss: 1.7392 - val_accuracy: 0.4036 - val_loss: 1.6810
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3792 - loss: 1.7231 - val_accuracy: 0.4055 - val_loss: 1.6664
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3894 - loss: 1.7027 - val_accuracy: 0.4235 - val_loss: 1.6342
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3981 - loss: 1.6905 - val_accuracy: 0.4190 - val_loss: 1.6403
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3978 - loss: 1.6810 - val_accuracy: 0.4364 - val_loss: 1.6155
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3963 - loss: 1.6714 - val_accuracy: 0.4249 - val_loss: 1.6327
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4066 - loss: 1.6697 - val_accuracy: 0.4309 - val_loss: 1.6229
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4000 - loss: 1.6665 - val_accuracy: 0.4394 - val_loss: 1.6035
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4071 - loss: 1.6524 - val_accuracy: 0.4372 - val_loss: 1.5823
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4110 - loss: 1.6415 - val_accuracy: 0.4422 - val_loss: 1.5883
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4161 - loss: 1.6412 - val_accuracy: 0.4420 - val_loss: 1.5885
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4133 - loss: 1.6403 - val_accuracy: 0.4485 - val_loss: 1.5781
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4209 - loss: 1.6230 - val_accuracy: 0.4362 - val_loss: 1.5912
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4228 - loss: 1.6130 - val_accuracy: 0.4405 - val_loss: 1.5908
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4218 - loss: 1.6143 - val_accuracy: 0.4383 - val_loss: 1.5944
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4237 - loss: 1.6134 - val_accuracy: 0.4401 - val_loss: 1.5875
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4260 - loss: 1.6078 - val_accuracy: 0.4422 - val_loss: 1.5778
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4199 - loss: 1.6038 - val_accuracy: 0.4454 - val_loss: 1.5684
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4231 - loss: 1.6155 - val_accuracy: 0.4385 - val_loss: 1.5902
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4272 - loss: 1.5878 - val_accuracy: 0.4515 - val_loss: 1.5530
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4328 - loss: 1.5804 - val_accuracy: 0.4606 - val_loss: 1.5402
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4362 - loss: 1.5761 - val_accuracy: 0.4498 - val_loss: 1.5520
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4291 - loss: 1.5754 - val_accuracy: 0.4538 - val_loss: 1.5495
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4352 - loss: 1.5823 - val_accuracy: 0.4568 - val_loss: 1.5458
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4404 - loss: 1.5646 - val_accuracy: 0.4507 - val_loss: 1.5602
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4369 - loss: 1.5691 - val_accuracy: 0.4400 - val_loss: 1.5997
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4331 - loss: 1.5820 - val_accuracy: 0.4615 - val_loss: 1.5397
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4419 - loss: 1.5577 - val_accuracy: 0.4646 - val_loss: 1.5252
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4401 - loss: 1.5575 - val_accuracy: 0.4680 - val_loss: 1.5275
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4442 - loss: 1.5482 - val_accuracy: 0.4568 - val_loss: 1.5443
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4331 - loss: 1.5636 - val_accuracy: 0.4630 - val_loss: 1.5504
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4472 - loss: 1.5370 - val_accuracy: 0.4553 - val_loss: 1.5567
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4446 - loss: 1.5455 - val_accuracy: 0.4525 - val_loss: 1.5456
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4465 - loss: 1.5333 - val_accuracy: 0.4523 - val_loss: 1.5592
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4427 - loss: 1.5604 - val_accuracy: 0.4627 - val_loss: 1.5432
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4428 - loss: 1.5476 - val_accuracy: 0.4619 - val_loss: 1.5375
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4458 - loss: 1.5444 - val_accuracy: 0.4716 - val_loss: 1.5138
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4499 - loss: 1.5415 - val_accuracy: 0.4614 - val_loss: 1.5298
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4504 - loss: 1.5397 - val_accuracy: 0.4671 - val_loss: 1.5350
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4492 - loss: 1.5393 - val_accuracy: 0.4588 - val_loss: 1.5423
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4489 - loss: 1.5225 - val_accuracy: 0.4628 - val_loss: 1.5308
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4520 - loss: 1.5322 - val_accuracy: 0.4639 - val_loss: 1.5358
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4448 - loss: 1.5314 - val_accuracy: 0.4683 - val_loss: 1.5144
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4514 - loss: 1.5226 - val_accuracy: 0.4677 - val_loss: 1.5234
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4540 - loss: 1.5134 - val_accuracy: 0.4706 - val_loss: 1.5151
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4575 - loss: 1.5062 - val_accuracy: 0.4694 - val_loss: 1.5146
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4566 - loss: 1.5096 - val_accuracy: 0.4758 - val_loss: 1.5068
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4560 - loss: 1.5155 - val_accuracy: 0.4643 - val_loss: 1.5313
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4550 - loss: 1.5099 - val_accuracy: 0.4725 - val_loss: 1.5113
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4561 - loss: 1.5193 - val_accuracy: 0.4651 - val_loss: 1.5318
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4539 - loss: 1.5207 - val_accuracy: 0.4642 - val_loss: 1.5143
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4569 - loss: 1.5043 - val_accuracy: 0.4716 - val_loss: 1.5104
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4589 - loss: 1.5065 - val_accuracy: 0.4660 - val_loss: 1.5261
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4591 - loss: 1.4996 - val_accuracy: 0.4723 - val_loss: 1.5134
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4552 - loss: 1.5031 - val_accuracy: 0.4720 - val_loss: 1.5116
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4570 - loss: 1.5035 - val_accuracy: 0.4744 - val_loss: 1.5151
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4608 - loss: 1.4940 - val_accuracy: 0.4622 - val_loss: 1.5304
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4680 - loss: 1.4843 - val_accuracy: 0.4709 - val_loss: 1.5122
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4576 - loss: 1.4942 - val_accuracy: 0.4606 - val_loss: 1.5230
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4591 - loss: 1.4978 - val_accuracy: 0.4775 - val_loss: 1.5069
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4688 - loss: 1.4845 - val_accuracy: 0.4682 - val_loss: 1.5271
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4635 - loss: 1.4899 - val_accuracy: 0.4710 - val_loss: 1.5222
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4708 - loss: 1.4684 - val_accuracy: 0.4818 - val_loss: 1.5015
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4638 - loss: 1.4811 - val_accuracy: 0.4730 - val_loss: 1.5156
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4717 - loss: 1.4799 - val_accuracy: 0.4690 - val_loss: 1.5235
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4693 - loss: 1.4781 - val_accuracy: 0.4730 - val_loss: 1.5059
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4656 - loss: 1.4798 - val_accuracy: 0.4686 - val_loss: 1.5431
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4603 - loss: 1.4902 - val_accuracy: 0.4764 - val_loss: 1.5109
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4665 - loss: 1.4734 - val_accuracy: 0.4643 - val_loss: 1.5335
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4700 - loss: 1.4668 - val_accuracy: 0.4676 - val_loss: 1.5251
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4771 - loss: 1.4561 - val_accuracy: 0.4724 - val_loss: 1.5221
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4729 - loss: 1.4687 - val_accuracy: 0.4653 - val_loss: 1.5373
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4673 - loss: 1.4731 - val_accuracy: 0.4695 - val_loss: 1.5189
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4717 - loss: 1.4602 - val_accuracy: 0.4623 - val_loss: 1.5320
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4671 - loss: 1.4704 - val_accuracy: 0.4788 - val_loss: 1.5020
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4679 - loss: 1.4704 - val_accuracy: 0.4818 - val_loss: 1.5124
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4774 - loss: 1.4541 - val_accuracy: 0.4783 - val_loss: 1.5088
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4687 - loss: 1.4653 - val_accuracy: 0.4676 - val_loss: 1.5203
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4769 - loss: 1.4537 - val_accuracy: 0.4791 - val_loss: 1.5083
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4766 - loss: 1.4548 - val_accuracy: 0.4706 - val_loss: 1.5093
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4762 - loss: 1.4484 - val_accuracy: 0.4722 - val_loss: 1.5276
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4747 - loss: 1.4570 - val_accuracy: 0.4692 - val_loss: 1.5275
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4803 - loss: 1.4407 - val_accuracy: 0.4571 - val_loss: 1.5397
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4772 - loss: 1.4531 - val_accuracy: 0.4733 - val_loss: 1.5139
# Epoch 91/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4795 - loss: 1.4413 - val_accuracy: 0.4735 - val_loss: 1.5394
# Epoch 92/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4759 - loss: 1.4586 - val_accuracy: 0.4783 - val_loss: 1.5118
# Epoch 93/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4774 - loss: 1.4505 - val_accuracy: 0.4650 - val_loss: 1.5340
# Epoch 94/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4759 - loss: 1.4514 - val_accuracy: 0.4653 - val_loss: 1.5295
# Epoch 95/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4763 - loss: 1.4512 - val_accuracy: 0.4785 - val_loss: 1.5153
# Epoch 96/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4734 - loss: 1.4416 - val_accuracy: 0.4728 - val_loss: 1.5276
# Epoch 97/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4789 - loss: 1.4365 - val_accuracy: 0.4597 - val_loss: 1.5310
# Epoch 98/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4827 - loss: 1.4269 - val_accuracy: 0.4757 - val_loss: 1.5104
# Epoch 99/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4782 - loss: 1.4411 - val_accuracy: 0.4788 - val_loss: 1.5110
# Epoch 100/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4824 - loss: 1.4315 - val_accuracy: 0.4781 - val_loss: 1.5101
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.1913 - loss: 0.7078 - val_accuracy: 0.3030 - val_loss: 0.3541
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3031 - loss: 0.3581 - val_accuracy: 0.3517 - val_loss: 0.3245
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3326 - loss: 0.3386 - val_accuracy: 0.3582 - val_loss: 0.3237
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3529 - loss: 0.3282 - val_accuracy: 0.3356 - val_loss: 0.3248
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3563 - loss: 0.3215 - val_accuracy: 0.3371 - val_loss: 0.3466
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3658 - loss: 0.3159 - val_accuracy: 0.3861 - val_loss: 0.3080
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3734 - loss: 0.3106 - val_accuracy: 0.3621 - val_loss: 0.3200
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3818 - loss: 0.3048 - val_accuracy: 0.4177 - val_loss: 0.2856
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3812 - loss: 0.3047 - val_accuracy: 0.4089 - val_loss: 0.2947
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3891 - loss: 0.3019 - val_accuracy: 0.4092 - val_loss: 0.2894
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3971 - loss: 0.2972 - val_accuracy: 0.4038 - val_loss: 0.2910
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3993 - loss: 0.2968 - val_accuracy: 0.3946 - val_loss: 0.2970
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4084 - loss: 0.2905 - val_accuracy: 0.4039 - val_loss: 0.2930
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4094 - loss: 0.2888 - val_accuracy: 0.4123 - val_loss: 0.2888
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4126 - loss: 0.2869 - val_accuracy: 0.4217 - val_loss: 0.2853
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4171 - loss: 0.2849 - val_accuracy: 0.4262 - val_loss: 0.2882
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4147 - loss: 0.2838 - val_accuracy: 0.4030 - val_loss: 0.2964
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4186 - loss: 0.2825 - val_accuracy: 0.4099 - val_loss: 0.2844
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4215 - loss: 0.2816 - val_accuracy: 0.4482 - val_loss: 0.2725
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4228 - loss: 0.2787 - val_accuracy: 0.4513 - val_loss: 0.2700
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4252 - loss: 0.2760 - val_accuracy: 0.4363 - val_loss: 0.2749
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4284 - loss: 0.2739 - val_accuracy: 0.4297 - val_loss: 0.2775
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4371 - loss: 0.2739 - val_accuracy: 0.4484 - val_loss: 0.2756
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4288 - loss: 0.2737 - val_accuracy: 0.4373 - val_loss: 0.2777
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4330 - loss: 0.2717 - val_accuracy: 0.4415 - val_loss: 0.2766
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4343 - loss: 0.2705 - val_accuracy: 0.4342 - val_loss: 0.2822
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4457 - loss: 0.2648 - val_accuracy: 0.4435 - val_loss: 0.2738
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4437 - loss: 0.2680 - val_accuracy: 0.4489 - val_loss: 0.2751
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4476 - loss: 0.2654 - val_accuracy: 0.4274 - val_loss: 0.2817
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4454 - loss: 0.2647 - val_accuracy: 0.4403 - val_loss: 0.2759
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4412 - loss: 0.2638 - val_accuracy: 0.4293 - val_loss: 0.2850
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4495 - loss: 0.2613 - val_accuracy: 0.4349 - val_loss: 0.2850
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4557 - loss: 0.2583 - val_accuracy: 0.4516 - val_loss: 0.2746
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4547 - loss: 0.2568 - val_accuracy: 0.4587 - val_loss: 0.2665
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4557 - loss: 0.2583 - val_accuracy: 0.4628 - val_loss: 0.2713
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4611 - loss: 0.2565 - val_accuracy: 0.4601 - val_loss: 0.2689
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4564 - loss: 0.2574 - val_accuracy: 0.4535 - val_loss: 0.2710
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4611 - loss: 0.2545 - val_accuracy: 0.4641 - val_loss: 0.2661
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4597 - loss: 0.2555 - val_accuracy: 0.3713 - val_loss: 0.3417
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4629 - loss: 0.2557 - val_accuracy: 0.4483 - val_loss: 0.2734
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4639 - loss: 0.2531 - val_accuracy: 0.4764 - val_loss: 0.2642
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4667 - loss: 0.2518 - val_accuracy: 0.4459 - val_loss: 0.2766
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4629 - loss: 0.2543 - val_accuracy: 0.4718 - val_loss: 0.2661
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4703 - loss: 0.2487 - val_accuracy: 0.4705 - val_loss: 0.2630
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4717 - loss: 0.2476 - val_accuracy: 0.4471 - val_loss: 0.2826
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4721 - loss: 0.2490 - val_accuracy: 0.4653 - val_loss: 0.2683
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4697 - loss: 0.2487 - val_accuracy: 0.4267 - val_loss: 0.3162
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4672 - loss: 0.2481 - val_accuracy: 0.4396 - val_loss: 0.2766
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4754 - loss: 0.2462 - val_accuracy: 0.4163 - val_loss: 0.3195
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4730 - loss: 0.2451 - val_accuracy: 0.4656 - val_loss: 0.2701
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4770 - loss: 0.2441 - val_accuracy: 0.4727 - val_loss: 0.2689
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4704 - loss: 0.2466 - val_accuracy: 0.4503 - val_loss: 0.2803
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4766 - loss: 0.2445 - val_accuracy: 0.4462 - val_loss: 0.2730
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4779 - loss: 0.2428 - val_accuracy: 0.4438 - val_loss: 0.2778
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4859 - loss: 0.2419 - val_accuracy: 0.4437 - val_loss: 0.2757
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4838 - loss: 0.2411 - val_accuracy: 0.4716 - val_loss: 0.2678
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4845 - loss: 0.2389 - val_accuracy: 0.4453 - val_loss: 0.2831
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4844 - loss: 0.2388 - val_accuracy: 0.4556 - val_loss: 0.2748
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4900 - loss: 0.2389 - val_accuracy: 0.4723 - val_loss: 0.2670
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4820 - loss: 0.2365 - val_accuracy: 0.4224 - val_loss: 0.2813
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4883 - loss: 0.2385 - val_accuracy: 0.4723 - val_loss: 0.2760
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4896 - loss: 0.2354 - val_accuracy: 0.4568 - val_loss: 0.2774
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4937 - loss: 0.2342 - val_accuracy: 0.4860 - val_loss: 0.2635
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4932 - loss: 0.2355 - val_accuracy: 0.4599 - val_loss: 0.2846
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4940 - loss: 0.2322 - val_accuracy: 0.4702 - val_loss: 0.2723
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4917 - loss: 0.2356 - val_accuracy: 0.4630 - val_loss: 0.2748
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4921 - loss: 0.2334 - val_accuracy: 0.4587 - val_loss: 0.2775
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4933 - loss: 0.2349 - val_accuracy: 0.4591 - val_loss: 0.2786
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4974 - loss: 0.2321 - val_accuracy: 0.4668 - val_loss: 0.2813
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5005 - loss: 0.2304 - val_accuracy: 0.4537 - val_loss: 0.2800
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4970 - loss: 0.2319 - val_accuracy: 0.4665 - val_loss: 0.2750
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4957 - loss: 0.2303 - val_accuracy: 0.4648 - val_loss: 0.2834
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4956 - loss: 0.2297 - val_accuracy: 0.4709 - val_loss: 0.2740
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4971 - loss: 0.2293 - val_accuracy: 0.4557 - val_loss: 0.2776
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4962 - loss: 0.2319 - val_accuracy: 0.4671 - val_loss: 0.2927
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4996 - loss: 0.2290 - val_accuracy: 0.4599 - val_loss: 0.2791
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5060 - loss: 0.2270 - val_accuracy: 0.4622 - val_loss: 0.2787
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5011 - loss: 0.2276 - val_accuracy: 0.4463 - val_loss: 0.2855
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4977 - loss: 0.2278 - val_accuracy: 0.4510 - val_loss: 0.2964
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5024 - loss: 0.2253 - val_accuracy: 0.4628 - val_loss: 0.2916
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5060 - loss: 0.2253 - val_accuracy: 0.4810 - val_loss: 0.2727
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5064 - loss: 0.2266 - val_accuracy: 0.4670 - val_loss: 0.2806
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5086 - loss: 0.2240 - val_accuracy: 0.4496 - val_loss: 0.2906
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5018 - loss: 0.2234 - val_accuracy: 0.4722 - val_loss: 0.2774
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5073 - loss: 0.2242 - val_accuracy: 0.4184 - val_loss: 0.2989
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5148 - loss: 0.2189 - val_accuracy: 0.4774 - val_loss: 0.2775
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5109 - loss: 0.2201 - val_accuracy: 0.4787 - val_loss: 0.2730
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5126 - loss: 0.2190 - val_accuracy: 0.4818 - val_loss: 0.2755
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5120 - loss: 0.2228 - val_accuracy: 0.4285 - val_loss: 0.3006
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5154 - loss: 0.2218 - val_accuracy: 0.4716 - val_loss: 0.2805
# Epoch 91/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5081 - loss: 0.2218 - val_accuracy: 0.4629 - val_loss: 0.3115
# Epoch 92/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5117 - loss: 0.2208 - val_accuracy: 0.4786 - val_loss: 0.2815
# Epoch 93/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5177 - loss: 0.2170 - val_accuracy: 0.4546 - val_loss: 0.2933
# Epoch 94/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5178 - loss: 0.2190 - val_accuracy: 0.4312 - val_loss: 0.3010
# Epoch 95/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5110 - loss: 0.2192 - val_accuracy: 0.4412 - val_loss: 0.2933
# Epoch 96/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5193 - loss: 0.2162 - val_accuracy: 0.4787 - val_loss: 0.2818
# Epoch 97/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5192 - loss: 0.2157 - val_accuracy: 0.4552 - val_loss: 0.2990
# Epoch 98/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5128 - loss: 0.2171 - val_accuracy: 0.4542 - val_loss: 0.3026
# Epoch 99/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5171 - loss: 0.2178 - val_accuracy: 0.4557 - val_loss: 0.2892
# Epoch 100/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5187 - loss: 0.2152 - val_accuracy: 0.4383 - val_loss: 0.2976
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2103 - loss: 0.5526 - val_accuracy: 0.3298 - val_loss: 0.3511
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3070 - loss: 0.3527 - val_accuracy: 0.3594 - val_loss: 0.3245
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3344 - loss: 0.3367 - val_accuracy: 0.3646 - val_loss: 0.3178
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3366 - loss: 0.3278 - val_accuracy: 0.3621 - val_loss: 0.3146
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3472 - loss: 0.3226 - val_accuracy: 0.3816 - val_loss: 0.3086
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3547 - loss: 0.3205 - val_accuracy: 0.3815 - val_loss: 0.3070
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3553 - loss: 0.3181 - val_accuracy: 0.3855 - val_loss: 0.2985
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3680 - loss: 0.3116 - val_accuracy: 0.3948 - val_loss: 0.3033
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3632 - loss: 0.3130 - val_accuracy: 0.4074 - val_loss: 0.2934
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3643 - loss: 0.3121 - val_accuracy: 0.4103 - val_loss: 0.2914
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3783 - loss: 0.3044 - val_accuracy: 0.4085 - val_loss: 0.2935
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3771 - loss: 0.3053 - val_accuracy: 0.3878 - val_loss: 0.2986
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3784 - loss: 0.3052 - val_accuracy: 0.4157 - val_loss: 0.2854
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3844 - loss: 0.2993 - val_accuracy: 0.4226 - val_loss: 0.2896
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3843 - loss: 0.3019 - val_accuracy: 0.4230 - val_loss: 0.2837
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3873 - loss: 0.2988 - val_accuracy: 0.4150 - val_loss: 0.2827
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3842 - loss: 0.3005 - val_accuracy: 0.4210 - val_loss: 0.2840
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3944 - loss: 0.2963 - val_accuracy: 0.4243 - val_loss: 0.2859
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3885 - loss: 0.2983 - val_accuracy: 0.4230 - val_loss: 0.2845
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3871 - loss: 0.2951 - val_accuracy: 0.4226 - val_loss: 0.2810
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3957 - loss: 0.2932 - val_accuracy: 0.4305 - val_loss: 0.2791
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3956 - loss: 0.2923 - val_accuracy: 0.4267 - val_loss: 0.2792
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3985 - loss: 0.2887 - val_accuracy: 0.4167 - val_loss: 0.2805
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4031 - loss: 0.2894 - val_accuracy: 0.4369 - val_loss: 0.2776
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3982 - loss: 0.2907 - val_accuracy: 0.4275 - val_loss: 0.2794
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3973 - loss: 0.2904 - val_accuracy: 0.4300 - val_loss: 0.2759
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3982 - loss: 0.2882 - val_accuracy: 0.4308 - val_loss: 0.2782
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4071 - loss: 0.2864 - val_accuracy: 0.4303 - val_loss: 0.2725
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4088 - loss: 0.2845 - val_accuracy: 0.4386 - val_loss: 0.2745
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4051 - loss: 0.2866 - val_accuracy: 0.4408 - val_loss: 0.2729
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4009 - loss: 0.2863 - val_accuracy: 0.4453 - val_loss: 0.2735
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4066 - loss: 0.2829 - val_accuracy: 0.4306 - val_loss: 0.2767
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4016 - loss: 0.2873 - val_accuracy: 0.4440 - val_loss: 0.2744
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4100 - loss: 0.2834 - val_accuracy: 0.4211 - val_loss: 0.2809
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4045 - loss: 0.2848 - val_accuracy: 0.4411 - val_loss: 0.2733
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4047 - loss: 0.2835 - val_accuracy: 0.4318 - val_loss: 0.2760
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4123 - loss: 0.2819 - val_accuracy: 0.4403 - val_loss: 0.2711
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4085 - loss: 0.2832 - val_accuracy: 0.4346 - val_loss: 0.2738
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4129 - loss: 0.2797 - val_accuracy: 0.4476 - val_loss: 0.2699
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4136 - loss: 0.2777 - val_accuracy: 0.4411 - val_loss: 0.2700
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4118 - loss: 0.2802 - val_accuracy: 0.4442 - val_loss: 0.2684
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4128 - loss: 0.2797 - val_accuracy: 0.4432 - val_loss: 0.2729
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4102 - loss: 0.2787 - val_accuracy: 0.4324 - val_loss: 0.2761
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4087 - loss: 0.2793 - val_accuracy: 0.4464 - val_loss: 0.2692
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4228 - loss: 0.2731 - val_accuracy: 0.4494 - val_loss: 0.2709
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4163 - loss: 0.2759 - val_accuracy: 0.4507 - val_loss: 0.2687
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4152 - loss: 0.2755 - val_accuracy: 0.4427 - val_loss: 0.2695
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4163 - loss: 0.2748 - val_accuracy: 0.4425 - val_loss: 0.2697
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4188 - loss: 0.2747 - val_accuracy: 0.4297 - val_loss: 0.2727
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4254 - loss: 0.2722 - val_accuracy: 0.4481 - val_loss: 0.2680
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4199 - loss: 0.2734 - val_accuracy: 0.4404 - val_loss: 0.2708
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4196 - loss: 0.2743 - val_accuracy: 0.4364 - val_loss: 0.2714
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4144 - loss: 0.2757 - val_accuracy: 0.4420 - val_loss: 0.2711
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4292 - loss: 0.2691 - val_accuracy: 0.4309 - val_loss: 0.2738
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4245 - loss: 0.2738 - val_accuracy: 0.4501 - val_loss: 0.2658
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4200 - loss: 0.2731 - val_accuracy: 0.4474 - val_loss: 0.2659
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4251 - loss: 0.2691 - val_accuracy: 0.4510 - val_loss: 0.2662
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4237 - loss: 0.2727 - val_accuracy: 0.4473 - val_loss: 0.2738
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4253 - loss: 0.2692 - val_accuracy: 0.4383 - val_loss: 0.2698
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4195 - loss: 0.2713 - val_accuracy: 0.4452 - val_loss: 0.2682
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4222 - loss: 0.2702 - val_accuracy: 0.4438 - val_loss: 0.2689
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4248 - loss: 0.2683 - val_accuracy: 0.4348 - val_loss: 0.2722
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4254 - loss: 0.2719 - val_accuracy: 0.4462 - val_loss: 0.2679
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4279 - loss: 0.2687 - val_accuracy: 0.4375 - val_loss: 0.2733
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4210 - loss: 0.2707 - val_accuracy: 0.4483 - val_loss: 0.2659
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4319 - loss: 0.2651 - val_accuracy: 0.4464 - val_loss: 0.2673
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4272 - loss: 0.2683 - val_accuracy: 0.4439 - val_loss: 0.2698
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4237 - loss: 0.2666 - val_accuracy: 0.4478 - val_loss: 0.2679
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4273 - loss: 0.2674 - val_accuracy: 0.4514 - val_loss: 0.2651
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4271 - loss: 0.2704 - val_accuracy: 0.4441 - val_loss: 0.2679
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4305 - loss: 0.2656 - val_accuracy: 0.4523 - val_loss: 0.2665
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4273 - loss: 0.2665 - val_accuracy: 0.4488 - val_loss: 0.2663
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4322 - loss: 0.2650 - val_accuracy: 0.4549 - val_loss: 0.2628
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4361 - loss: 0.2640 - val_accuracy: 0.4447 - val_loss: 0.2723
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4341 - loss: 0.2660 - val_accuracy: 0.4382 - val_loss: 0.2700
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4285 - loss: 0.2656 - val_accuracy: 0.4491 - val_loss: 0.2667
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4295 - loss: 0.2648 - val_accuracy: 0.4499 - val_loss: 0.2657
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4337 - loss: 0.2629 - val_accuracy: 0.4462 - val_loss: 0.2655
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4346 - loss: 0.2627 - val_accuracy: 0.4454 - val_loss: 0.2688
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4310 - loss: 0.2649 - val_accuracy: 0.4467 - val_loss: 0.2679
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4311 - loss: 0.2639 - val_accuracy: 0.4525 - val_loss: 0.2675
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4374 - loss: 0.2613 - val_accuracy: 0.4463 - val_loss: 0.2699
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4353 - loss: 0.2627 - val_accuracy: 0.4434 - val_loss: 0.2717
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4332 - loss: 0.2617 - val_accuracy: 0.4548 - val_loss: 0.2643
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4341 - loss: 0.2627 - val_accuracy: 0.4452 - val_loss: 0.2688
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4315 - loss: 0.2624 - val_accuracy: 0.4531 - val_loss: 0.2656
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4372 - loss: 0.2626 - val_accuracy: 0.4431 - val_loss: 0.2705
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4421 - loss: 0.2598 - val_accuracy: 0.4495 - val_loss: 0.2688
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4295 - loss: 0.2604 - val_accuracy: 0.4481 - val_loss: 0.2674
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4320 - loss: 0.2619 - val_accuracy: 0.4457 - val_loss: 0.2667
# Epoch 91/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4364 - loss: 0.2612 - val_accuracy: 0.4561 - val_loss: 0.2636
# Epoch 92/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4386 - loss: 0.2586 - val_accuracy: 0.4423 - val_loss: 0.2700
# Epoch 93/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4391 - loss: 0.2607 - val_accuracy: 0.4504 - val_loss: 0.2673
# Epoch 94/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4387 - loss: 0.2622 - val_accuracy: 0.4554 - val_loss: 0.2669
# Epoch 95/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4298 - loss: 0.2632 - val_accuracy: 0.4508 - val_loss: 0.2660
# Epoch 96/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4323 - loss: 0.2595 - val_accuracy: 0.4510 - val_loss: 0.2644
# Epoch 97/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4378 - loss: 0.2576 - val_accuracy: 0.4418 - val_loss: 0.2668
# Epoch 98/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4353 - loss: 0.2589 - val_accuracy: 0.4496 - val_loss: 0.2706
# Epoch 99/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4395 - loss: 0.2599 - val_accuracy: 0.4444 - val_loss: 0.2682
# Epoch 100/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4427 - loss: 0.2558 - val_accuracy: 0.4480 - val_loss: 0.2677

# %%
print("RMSprop, categorical_crossentropy")
disp_performance(mRMS_cat, history1)
print("Adam, categorical_crossentropy")
disp_performance(mAdam_cat, history2)
print("RMSprop, categorical_focal_crossentropy")
disp_performance(mRMS_focal, history3)
print("Adam, categorical_focal_crossentropy")
disp_performance(mAdam_focal, history4)
# Out:
# RMSprop, categorical_crossentropy
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.4536 - loss: 1.6408
# Test Accuracy: 0.4481000006198883
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.35      0.43      1000
#            1       0.60      0.51      0.55      1000
#            2       0.31      0.41      0.35      1000
#            3       0.33      0.26      0.29      1000
#            4       0.49      0.28      0.36      1000
#            5       0.34      0.47      0.39      1000
#            6       0.53      0.50      0.51      1000
#            7       0.64      0.44      0.52      1000
#            8       0.39      0.81      0.53      1000
#            9       0.56      0.46      0.51      1000
#
#     accuracy                           0.45     10000
#    macro avg       0.48      0.45      0.44     10000
# weighted avg       0.48      0.45      0.44     10000
# Adam, categorical_crossentropy
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.4745 - loss: 1.4843
# Test Accuracy: 0.4717000126838684
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.47      0.60      0.53      1000
#            1       0.63      0.53      0.58      1000
#            2       0.35      0.27      0.31      1000
#            3       0.31      0.37      0.34      1000
#            4       0.39      0.45      0.42      1000
#            5       0.43      0.34      0.38      1000
#            6       0.47      0.59      0.52      1000
#            7       0.56      0.53      0.54      1000
#            8       0.60      0.57      0.58      1000
#            9       0.57      0.47      0.51      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.48      0.47      0.47     10000
# weighted avg       0.48      0.47      0.47     10000
# RMSprop, categorical_focal_crossentropy
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.4349 - loss: 0.2871
# Test Accuracy: 0.43540000915527344
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      0.52      0.48      1000
#            1       0.58      0.56      0.57      1000
#            2       0.36      0.17      0.23      1000
#            3       0.35      0.23      0.28      1000
#            4       0.28      0.69      0.40      1000
#            5       0.41      0.31      0.35      1000
#            6       0.53      0.52      0.52      1000
#            7       0.52      0.49      0.50      1000
#            8       0.50      0.59      0.54      1000
#            9       0.60      0.28      0.38      1000
#
#     accuracy                           0.44     10000
#    macro avg       0.46      0.44      0.43     10000
# weighted avg       0.46      0.44      0.43     10000
# Adam, categorical_focal_crossentropy
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.4437 - loss: 0.2583
# Test Accuracy: 0.4413999915122986
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.41      0.46      1000
#            1       0.62      0.44      0.51      1000
#            2       0.29      0.31      0.30      1000
#            3       0.33      0.20      0.25      1000
#            4       0.36      0.45      0.40      1000
#            5       0.44      0.29      0.35      1000
#            6       0.42      0.63      0.50      1000
#            7       0.49      0.49      0.49      1000
#            8       0.50      0.65      0.57      1000
#            9       0.48      0.55      0.51      1000
#
#     accuracy                           0.44     10000
#    macro avg       0.45      0.44      0.43     10000
# weighted avg       0.45      0.44      0.43     10000

# %% [markdown]
# ## 6 Scaling up: developing a model that overfits
# ```Once you’ve obtained a model that has statistical power, the question becomes, is your model sufficiently powerful? Does it have enough layers and parameters to properly model the problem at hand? For instance, a network with a single hidden layer with two units would have statistical power on MNIST but wouldn’t be sufficient to solve the problem well. Remember that the universal tension in machine learning is between optimization and generalization; the ideal model is one that stands right at the border between underfitting and overfitting; between undercapacity and overcapacity. To figure out where this border lies, first you must cross it.```
#
# ```To figure out how big a model you’ll need, you must develop a model that overfits. This is fairly easy:```
# 1. Add layers
# 2. Make the layers bigger
# 3. Train for more epochs
#
# ```Always monitor the training loss and validation loss, as well as the training and validation values for any metrics you care about. When you see that the model’s performance on the validation data begins to degrade, you’ve achieved overfitting.```
#
# ```The next stage is to start regularizing and tuning the model, to get as close as possible to the ideal model that neither underfits nor overfits.```

# %% [markdown]
# ## 7 Regularizing your model and tuning your hyperparameters
# ```This step will take the most time: you’ll repeatedly modify your model, train it, evaluate on your validation data (not the test data, at this point), modify it again, and repeat, until the model is as good as it can get. These are some things you should try:```
#
# - Add dropout
# - Try different architectures: add or remove layers
# - Add L1 and/or L2 regularization
# - Try different hyperparameters (such as the number of units per layer or the learning rate of the optimizer) to find the optimal configuration
# - Optionally, iterate on feature engineering: add new features, or remove features that don’t seem to be informative
#
# ```Be mindful of the following: every time you use feedback from your validation process to tune your model, you leak information about the validation process into the model. Repeated just a few times, this is innocuous; but done systematically over many iterations, it will eventually cause your model to overfit to the validation process (even though no model is directly trained on any of the validation data). This makes the evaluation process less reliable.```
#
# ```Once you’ve developed a satisfactory model configuration, you can train your final production model on all the available data (training and validation) and evaluate it one last time on the test set. If it turns out that performance on the test set is significantly worse than the performance measured on the validation data, this may mean either that your validation procedure wasn’t reliable after all, or that you began overfitting to the validation data while tuning the parameters of the model. In this case, you may want to switch to a more reliable evaluation protocol (such as iterated K-fold validation).```

# %% [markdown]
# ## 8 References
# 1. Keras (n.d.). Keras documentation: CIFAR10 Small Images Classification Dataset. [online] keras.io. Available at: https://keras.io/api/datasets/cifar10/.
# 2. Bleyer, A. and Welch, H.G. (2012). Effect of Three Decades of Screening Mammography on Breast-Cancer Incidence. New England Journal of Medicine, 367(21), pp.1998–2005. doi:https://doi.org/10.1056/nejmoa1206809.
# 3. Krizhevsky, A. (2009). CIFAR-10 and CIFAR-100 datasets. [online] Toronto.edu. Available at: https://www.cs.toronto.edu/~kriz/cifar.html.
